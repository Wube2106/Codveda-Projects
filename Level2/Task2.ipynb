# %% [markdown]
# # Task 2:Decision Trees for Classification

# %%
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %% [markdown]
# ## Load the dataset

# %%
# load the dataset
df = pd.read_csv(r"C:/Users/Hp/Documents/My project/Codveda Projects/Dataset/1) iris.csv")
df.head()
df.info()

# %% [markdown]
# ## Handling the dataset
# I get duplicate values and I dropped them.

# %%
# handling the dataset
print("Before handling missing values:",df.isnull().sum())
print("Before handling duplicates:",df.duplicated().sum())
df=df.drop_duplicates()
print("After handling duplicates:",df.duplicated().sum())

# %% [markdown]
# ## Feature and Target Selection

# %%
#feature and target selection
X=df.drop(columns="species",axis=1,errors="ignore")
y=df["species"]
X

# %% [markdown]
# ## Train and Test Split

# %%
#train test split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,shuffle=True,random_state=42)

# %% [markdown]
# ## Train and Prune Model
#
# A Decision Tree Classifier was trained on the training dataset to learn decision rules for classifying Iris species.
#
# To prevent overfitting, **pre-pruning** was applied by limiting the tree depth using `max_depth=3`. This helps the model generalize better on unseen data by controlling model complexity.

# %%
# train the model using decision tree and pruning the tree
model = DecisionTreeClassifier(
    random_state=42,
    max_depth=3
)
model.fit(X_train,y_train)

y_pred=model.predict(X_test)
print(y_pred[:10])
print(y_test[:10])

# %% [markdown]
# ## Visualize Tree Structure
#
# The trained Decision Tree was visualized using `plot_tree()` to understand how decisions are made at each node.
#
# The visualization shows:
# - Feature-based splitting rules
# - Gini impurity at each node
# - Class distribution
# - Final predicted class at leaf nodes
#
# This helps interpret how the model classifies different Iris species.

# %%
#visualization the model tree stucture
plt.figure(figsize=(15,10))

plot_tree(
  model,
  feature_names=X.columns,
  class_names=model.classes_,
  filled=True,
  rounded=True
)

plt.show()

# %%
# Evaluation
accuracy=accuracy_score(y_test,y_pred)
f1=f1_score(y_test,y_pred,average="macro")
cm=confusion_matrix(y_test,y_pred)
Classification_report=classification_report(y_test,y_pred)
print("Accuracy:",accuracy)
print("F1_score:",f1)
print("\n Classification_report: \n",Classification_report)
print("\n Confusion matrix:\n",cm)

# %% [markdown]
# ## Model Evaluation
#
# The model was evaluated using Accuracy, F1-score, Classification Report, and Confusion Matrix.
#
# ### Results:
# - **Accuracy:** 0.90
# - **F1 Score:** 0.8936
#
# ### Classification Report:
# - Setosa: Perfect classification (1.00 F1-score)
# - Versicolor: Good performance with minor misclassification
# - Virginica: Slight confusion with Versicolor samples
#
# ### Confusion Matrix:
# [[11  0  0]
#  [ 0  9  1]
#  [ 0  2  7]]
#
# ### Conclusion:
# The model performs well overall with strong accuracy and balanced F1-score, showing effective classification after pruning.
